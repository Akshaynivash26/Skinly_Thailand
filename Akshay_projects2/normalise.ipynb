# %%
import pandas as pd
import numpy as np

# Read the CSV file
df = pd.read_csv('/home/azureuser/cloudfiles/code/Users/Akshayanivashini.ChandrasekarVijayalakshmi/Skinly_Thailand/Akshay_projects2/updated_thai_chunkid.csv')

# %%
# Define a function to remove outliers using the z-score method
def remove_outliers_zscore(df, features, threshold=3):
    z_scores = np.abs((df[features] - df[features].mean()) / df[features].std())
    df = df[(z_scores < threshold).all(axis=1)]
    return df

# %%
# Define a list of features to check for outliers
features = ['moisture_cheek', 'moisture_forearm', 'moisture_forehead', 'shininess_cheek', 'shininess_forehead', 'evenness_cheek', 'evenness_forearm', 'evenness_red_cheek', 'evenness_red_forearm', 'evenness_red_forehead', 'ita_cheek', 'ita_forearm', 'ita_forehead', 'melanin_cheek', 'melanin_forearm', 'melanin_forehead', 'vessels_den_cheek', 'vessels_den_forearm', 'vessels_den_forehead', 'skin_texture_cheek', 'skin_texture_forearm', 'skin_texture_forehead', 'fine_lines_cheek', 'fine_lines_forearm', 'fine_lines_forehead', 'deep_lines_forehead', 'cheek_age_dif', 'forearm_age_dif', 'forehead_age_dif', 'G_porph_L_MEAN_cheek', 'G_porph_L_MEAN_forehead', 'G_porph_NUMBER_cheek', 'G_porph_NUMBER_forehead', 'R_porph_L_MEAN_cheek', 'R_porph_L_MEAN_forehead', 'R_porph_NUMBER_cheek', 'R_porph_NUMBER_forehead', 'Y_porph_L_MEAN_cheek', 'Y_porph_L_MEAN_forehead', 'Y_porph_NUMBER_cheek', 'Y_porph_NUMBER_forehead', 'redness_cheek', 'redness_forearm', 'redness_forehead']

# %%
# Remove outliers using the z-score method
df = remove_outliers_zscore(df, features)

# %%
# Save the updated data to a new CSV file
df.to_csv('outliers_removed_thai.csv', index=False)

# %%
df.head()
# Out:
#      user_id        date chunkiduser  moisture_cheek  moisture_forearm  \
# 94      3154  2023-04-23      chunk1           100.0              56.0
# 98      3154  2023-04-27      chunk1            21.0              46.0
# 108     3154  2023-05-07      chunk1            40.0              39.0
# 110     3154  2023-05-09      chunk1            14.0              39.0
# 225     3181  2022-01-22      chunk1            91.0              83.0
#
#      moisture_forehead  shininess_cheek  shininess_forehead  evenness_cheek  \
# 94                76.0              3.0                33.0            36.0
# 98                48.0              3.0                37.0            63.0
# 108               39.0             10.0                28.0            61.0
# 110               38.0              2.0                27.0            45.0
# 225               88.0             69.0                82.0            49.0
#
#      evenness_forearm  ...  R_porph_L_MEAN_forehead  R_porph_NUMBER_cheek  \
# ...

# %% [markdown]
# ### Normalization using Min-Max

# %%
! pip install scikit-learn

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
# Read the CSV file
df = pd.read_csv('/home/azureuser/cloudfiles/code/Users/Akshayanivashini.ChandrasekarVijayalakshmi/Skinly_Thailand/Akshay_projects2/outliers_removed_thai.csv')

# %%
# Define a list of features to normalize and scale
features = ['moisture_cheek', 'moisture_forearm', 'moisture_forehead', 'shininess_cheek', 'shininess_forehead', 'evenness_cheek', 'evenness_forearm', 'evenness_red_cheek', 'evenness_red_forearm', 'evenness_red_forehead', 'ita_cheek', 'ita_forearm', 'ita_forehead', 'melanin_cheek', 'melanin_forearm', 'melanin_forehead', 'vessels_den_cheek', 'vessels_den_forearm', 'vessels_den_forehead', 'skin_texture_cheek', 'skin_texture_forearm', 'skin_texture_forehead', 'fine_lines_cheek', 'fine_lines_forearm', 'fine_lines_forehead', 'deep_lines_forehead', 'cheek_age_dif', 'forearm_age_dif', 'forehead_age_dif', 'G_porph_L_MEAN_cheek', 'G_porph_L_MEAN_forehead', 'G_porph_NUMBER_cheek', 'G_porph_NUMBER_forehead', 'R_porph_L_MEAN_cheek', 'R_porph_L_MEAN_forehead', 'R_porph_NUMBER_cheek', 'R_porph_NUMBER_forehead', 'Y_porph_L_MEAN_cheek', 'Y_porph_L_MEAN_forehead', 'Y_porph_NUMBER_cheek', 'Y_porph_NUMBER_forehead', 'redness_cheek', 'redness_forearm', 'redness_forehead']

# %%
# Normalize and scale the features to the range 0-100
scaler = MinMaxScaler(feature_range=(0, 100))
df[features] = scaler.fit_transform(df[features])

# %%
# Save the updated data to a new CSV file
df.to_csv('normalised_thai.csv', index=False)

# %%
df.head()
# Out:
#    user_id        date chunkiduser  moisture_cheek  moisture_forearm  \
# 0     3154  2023-04-23      chunk1           100.0         54.166667
# 1     3154  2023-04-27      chunk1            21.0         43.750000
# 2     3154  2023-05-07      chunk1            40.0         36.458333
# 3     3154  2023-05-09      chunk1            14.0         36.458333
# 4     3181  2022-01-22      chunk1            91.0         82.291667
#
#    moisture_forehead  shininess_cheek  shininess_forehead  evenness_cheek  \
# 0               76.0         3.225806           30.927835       42.241379
# 1               48.0         3.225806           35.051546       65.517241
# 2               39.0        10.752688           25.773196       63.793103
# 3               38.0         2.150538           24.742268       50.000000
# 4               88.0        74.193548           81.443299       53.448276
#
#    evenness_forearm  ...  R_porph_L_MEAN_forehead  R_porph_NUMBER_cheek  \
# ...

# %%
import pandas as pd

# Load the dataset
dfout= pd.read_csv('/home/azureuser/cloudfiles/code/Users/Akshayanivashini.ChandrasekarVijayalakshmi/Skinly_Thailand/Akshay_projects2/outliers_removed_thai.csv')

# Calculate the z-scores for each column
z_scores = (dfout[dfout.columns[3:]] - dfout[dfout.columns[3:]].mean()) / dfout[dfout.columns[3:]].std()

# Scale the data between 0 and 100
scaled_data = z_scores * 50 + 50
# Clip the scaled values to a maximum of 100
scaled_data = scaled_data.clip(upper=100)

# Replace the original data with the scaled data
dfout[dfout.columns[3:]] = scaled_data

# Save the standardized and scaled data to a new CSV file
dfout.to_csv('z_score_normalized.csv', index=False)

# %%
from sklearn.preprocessing import StandardScaler

# %%
# Load the dataset
dfout2= pd.read_csv('/home/azureuser/cloudfiles/code/Users/Akshayanivashini.ChandrasekarVijayalakshmi/Skinly_Thailand/Akshay_projects2/outliers_removed_thai.csv')

# %%
# Select the columns to standardize
cols_to_standardize = dfout2.columns[3:]

# Standardize the data
scaler = StandardScaler()
dfout2[cols_to_standardize] = scaler.fit_transform(dfout2[cols_to_standardize])

# Scale the data between 0 and 100
dfout2[cols_to_standardize] = dfout2[cols_to_standardize] * 50 + 50

# Save the standardized and scaled data to a new CSV file
dfout2.to_csv('standardized_scaled.csv', index=False)

# %%
dfout
# Out:
#       user_id        date chunkiduser  moisture_cheek  moisture_forearm  \
# 0        3154  2023-04-23      chunk1      100.000000         49.201075
# 1        3154  2023-04-27      chunk1      -41.425534         20.355659
# 2        3154  2023-05-07      chunk1        8.354613          0.163867
# 3        3154  2023-05-09      chunk1      -59.765588          0.163867
# 4        3181  2022-01-22      chunk1      100.000000        100.000000
# ...       ...         ...         ...             ...               ...
# 8635    21590  2024-03-14      chunk1      -12.605449         29.009284
# 8636    21590  2024-03-15      chunk1        8.354613         20.355659
# 8637    21590  2024-03-16      chunk1       16.214636         40.547450
# 8638    21590  2024-03-17      chunk1       10.974621         34.778367
# 8639    21590  2024-03-18      chunk1       -4.745426         37.662909
#
#       moisture_forehead  shininess_cheek  shininess_forehead  evenness_cheek  \
# ...

# %%
dfout2.head()
# Out:
#    user_id        date chunkiduser  moisture_cheek  moisture_forearm  \
# 0     3154  2023-04-23      chunk1      165.561765         49.201029
# 1     3154  2023-04-27      chunk1      -41.430825         20.353943
# 2     3154  2023-05-07      chunk1        8.352203          0.160983
# 3     3154  2023-05-09      chunk1      -59.771941          0.160983
# 4     3181  2022-01-22      chunk1      141.980331        127.088162
#
#    moisture_forehead  shininess_cheek  shininess_forehead  evenness_cheek  \
# 0          92.846416       -87.987334          -18.028586       17.463534
# 1          20.812413       -87.987334           -6.673677       90.919972
# 2          -2.341374       -65.265454          -32.222222       85.478754
# 3          -4.914017       -91.233317          -35.060950       41.949013
# 4         123.718131       126.247537          121.069047       52.831448
#
#    evenness_forearm  ...  R_porph_L_MEAN_forehead  R_porph_NUMBER_cheek  \
# ...
