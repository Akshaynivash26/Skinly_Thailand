# %%
import pandas as pd

# Read the CSV file
df = pd.read_csv('/home/azureuser/cloudfiles/code/Users/Akshayanivashini.ChandrasekarVijayalakshmi/Skinly_Thailand/Akshay_projects2/thaiuser_chunkid_df.csv')

# %%
df.head()
# Out:
#    user_id        date chunkiduser  moisture_cheek  moisture_forearm  \
# 0     3154  2019-12-04         NaN            36.0              38.0
# 1     3154  2019-12-05         NaN            37.0              39.0
# 2     3154  2019-12-06         NaN            38.0              34.0
# 3     3154  2019-12-07         NaN            34.0              25.0
# 4     3154  2019-12-09         NaN            38.0              44.0
#
#    moisture_forehead  shininess_cheek  shininess_forehead  evenness_cheek  \
# 0               36.0             29.0                42.0            67.0
# 1               40.0             46.0                36.0            58.0
# 2               46.0             28.0                58.0            54.0
# 3               19.0             36.0                43.0            64.0
# 4               40.0             60.0                62.0            62.0
#
#    evenness_forearm  ...  R_porph_L_MEAN_forehead  R_porph_NUMBER_cheek  \
# ...

# %%
# Remove rows with no value in chunkiduser column
df = df[df['chunkiduser'].notna()]

# %%
df.head()
# Out:
#      user_id        date chunkiduser  moisture_cheek  moisture_forearm  \
# 569     3154  2023-01-19      chunk1            10.0              40.0
# 570     3154  2023-01-20      chunk1            22.0              42.0
# 571     3154  2023-01-21      chunk1            16.0              36.0
# 572     3154  2023-01-22      chunk1            18.0              45.0
# 573     3154  2023-01-23      chunk1            19.0              47.0
#
#      moisture_forehead  shininess_cheek  shininess_forehead  evenness_cheek  \
# 569               28.0              0.0                30.0            48.0
# 570               22.0              0.0                16.0            44.0
# 571               27.0              0.0                16.0            52.0
# 572               31.0              0.0                21.0            44.0
# 573               51.0              2.0                27.0            41.0
#
#      evenness_forearm  ...  R_porph_L_MEAN_forehead  R_porph_NUMBER_cheek  \
# ...

# %%
# Save the updated data to a new CSV file
df.to_csv('updated_thai_chunkid.csv', index=False)
